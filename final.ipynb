# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrajansk/Exploration/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. INSTALL DEPENDENCIES (if not preinstalled) ---
# !pip install -q pandas numpy scikit-learn tensorflow joblib

# --- 2. IMPORT LIBRARIES ---
import pandas as pd
import numpy as np
import os
import joblib
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# --- 3. LOAD DATA ---
train_df = pd.read_csv("/content/Training.csv")
test_df = pd.read_csv("/content/Testing.csv")

# Drop unnamed column if exists
if 'Unnamed: 133' in train_df.columns:
    train_df.drop('Unnamed: 133', axis=1, inplace=True)

# --- 4. DATA CHECKS ---
print("Training Shape:", train_df.shape)
print("Test Shape:", test_df.shape)
print("Nulls in Training:", train_df.isnull().sum().sum())
print("Unique Diseases:", train_df['prognosis'].nunique())

# --- 5. ENCODING & SPLIT ---
X_train = train_df.drop("prognosis", axis=1)
y_train = train_df["prognosis"]
X_test = test_df.drop("prognosis", axis=1)
y_test = test_df["prognosis"]

label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.transform(y_test)

# Save label encoder
os.makedirs("models", exist_ok=True)
joblib.dump(label_encoder, "models/label_encoder.pkl")

# --- 6. TRAIN-VAL SPLIT ---
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train_enc, test_size=0.2, stratify=y_train_enc, random_state=42
)

# --- 7. SCALING FOR NN ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_split)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

joblib.dump(scaler, "models/scaler.pkl")

# --- 8. RANDOM FOREST ---
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_split, y_train_split)

# Validation RF
rf_val_preds = rf_model.predict(X_val)
print("RF Val Accuracy:", accuracy_score(y_val, rf_val_preds))

# Save RF
joblib.dump(rf_model, "models/random_forest_model.pkl")

# --- 9. FEEDFORWARD NEURAL NETWORK ---
input_dim = X_train_scaled.shape[1]
num_classes = len(label_encoder.classes_)

fnn_model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
])

fnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

fnn_model.fit(X_train_scaled, y_train_split, validation_data=(X_val_scaled, y_val),
              epochs=100, batch_size=32, callbacks=[early_stop], verbose=1)

fnn_model.save("models/fnn_model.keras")

# --- 10. TEST EVALUATION ---

# RF
rf_preds_test = rf_model.predict(X_test)
print("RF Test Accuracy:", accuracy_score(y_test_enc, rf_preds_test))
print(classification_report(y_test_enc, rf_preds_test, target_names=label_encoder.classes_))

# FNN
fnn_preds_test = fnn_model.predict(X_test_scaled)
fnn_preds_class = np.argmax(fnn_preds_test, axis=1)
print("FNN Test Accuracy:", accuracy_score(y_test_enc, fnn_preds_class))
print(classification_report(y_test_enc, fnn_preds_class, target_names=label_encoder.classes_))

# --- 11. SAVE SYMPTOM LIST ---
symptom_list = list(X_train.columns)
joblib.dump(symptom_list, "models/symptom_list.pkl")
# Out:
# Training Shape: (4920, 133)
# Test Shape: (42, 133)
# Nulls in Training: 0
# Unique Diseases: 41
# RF Val Accuracy: 1.0
# Epoch 1/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4439 - loss: 2.4990 - val_accuracy: 1.0000 - val_loss: 0.0610
# Epoch 2/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.1445 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 3/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9954 - loss: 0.0466 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 4/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 5/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 7.4624e-04
# Epoch 6/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9999 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 4.1257e-04
# Epoch 7/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9991 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 4.0111e-04
# Epoch 8/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9992 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 2.2487e-04
# Epoch 9/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9984 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 1.4080e-04
# Epoch 10/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 1.2046e-04
# Epoch 11/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 6.9656e-05
# Epoch 12/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 5.6939e-05
# Epoch 13/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9994 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 5.5452e-05
# Epoch 14/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 4.1024e-05
# Epoch 15/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 7.9214e-05
# Epoch 16/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 2.0901e-05
# Epoch 17/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 1.6930e-05
# Epoch 18/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 2.0189e-05
# Epoch 19/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 1.2521e-05
# Epoch 20/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.9772e-05
# Epoch 21/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 2.4499e-05
# Epoch 22/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 7.0756e-06
# Epoch 23/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 4.5654e-06
# Epoch 24/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 2.6683e-05
# Epoch 25/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 5.3746e-06
# Epoch 26/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 7.8008e-04 - val_accuracy: 1.0000 - val_loss: 3.9919e-06
# Epoch 27/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.4525e-04 - val_accuracy: 1.0000 - val_loss: 2.5468e-05
# Epoch 28/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.3612e-04 - val_accuracy: 1.0000 - val_loss: 4.4286e-06
# Epoch 29/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.4324e-04 - val_accuracy: 1.0000 - val_loss: 3.0438e-06
# Epoch 30/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 3.1593e-06
# Epoch 31/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 2.5152e-06
# Epoch 32/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.9329e-04 - val_accuracy: 1.0000 - val_loss: 8.3687e-07
# Epoch 33/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 1.6703e-06
# Epoch 34/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 3.5938e-06
# Epoch 35/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6557e-04 - val_accuracy: 1.0000 - val_loss: 1.1179e-06
# Epoch 36/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 6.9501e-07
# Epoch 37/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.4490e-04 - val_accuracy: 1.0000 - val_loss: 8.1590e-07
# Epoch 38/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.2717e-04 - val_accuracy: 1.0000 - val_loss: 6.6302e-07
# Epoch 39/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.9337e-04 - val_accuracy: 1.0000 - val_loss: 5.2080e-07
# Epoch 40/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.2387e-04 - val_accuracy: 1.0000 - val_loss: 3.0941e-07
# Epoch 41/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.2076e-04 - val_accuracy: 1.0000 - val_loss: 2.6156e-07
# Epoch 42/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.7110e-04 - val_accuracy: 1.0000 - val_loss: 2.5307e-07
# Epoch 43/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.5177e-04 - val_accuracy: 1.0000 - val_loss: 3.8051e-07
# Epoch 44/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9995 - loss: 7.5307e-04 - val_accuracy: 1.0000 - val_loss: 5.0722e-07
# Epoch 45/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.7742e-04 - val_accuracy: 1.0000 - val_loss: 2.2005e-06
# Epoch 46/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 5.4235e-04 - val_accuracy: 1.0000 - val_loss: 4.0463e-07
# Epoch 47/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 7.8268e-04 - val_accuracy: 1.0000 - val_loss: 2.8450e-06
# Epoch 48/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.5060e-04 - val_accuracy: 1.0000 - val_loss: 2.0922e-07
# Epoch 49/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.7160e-04 - val_accuracy: 1.0000 - val_loss: 3.1231e-07
# Epoch 50/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.5984e-04 - val_accuracy: 1.0000 - val_loss: 2.2606e-07
# Epoch 51/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.9152e-04 - val_accuracy: 1.0000 - val_loss: 1.9832e-07
# Epoch 52/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2096e-04 - val_accuracy: 1.0000 - val_loss: 2.1697e-07
# Epoch 53/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 2.0725e-04 - val_accuracy: 1.0000 - val_loss: 1.5676e-07
# Epoch 54/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.9373e-04 - val_accuracy: 1.0000 - val_loss: 2.1092e-07
# Epoch 55/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.0177e-04 - val_accuracy: 1.0000 - val_loss: 3.1389e-07
# Epoch 56/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.8786e-04 - val_accuracy: 1.0000 - val_loss: 2.3793e-07
# Epoch 57/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.6163e-04 - val_accuracy: 1.0000 - val_loss: 1.2405e-07
# Epoch 58/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 2.4235e-04 - val_accuracy: 1.0000 - val_loss: 2.3857e-06
# Epoch 59/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8444e-04 - val_accuracy: 1.0000 - val_loss: 6.3602e-08
# Epoch 60/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.6822e-04 - val_accuracy: 1.0000 - val_loss: 8.5166e-08
# Epoch 61/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3357e-04 - val_accuracy: 1.0000 - val_loss: 5.8393e-08
# Epoch 62/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1189e-05 - val_accuracy: 1.0000 - val_loss: 3.9857e-08
# Epoch 63/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.5763e-04 - val_accuracy: 1.0000 - val_loss: 2.5199e-08
# Epoch 64/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1293e-04 - val_accuracy: 1.0000 - val_loss: 2.3503e-08
# Epoch 65/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3862e-04 - val_accuracy: 1.0000 - val_loss: 4.3492e-08
# Epoch 66/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 4.1979e-04 - val_accuracy: 1.0000 - val_loss: 1.3702e-07
# Epoch 67/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.3599e-04 - val_accuracy: 1.0000 - val_loss: 4.8216e-08
# Epoch 68/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.8874e-04 - val_accuracy: 1.0000 - val_loss: 1.5046e-07
# Epoch 69/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 1.2355e-04 - val_accuracy: 1.0000 - val_loss: 9.2919e-08
# Epoch 70/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 2.5087e-06
# Epoch 71/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 7.0162e-04 - val_accuracy: 1.0000 - val_loss: 1.4380e-07
# Epoch 72/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.2435e-04 - val_accuracy: 1.0000 - val_loss: 9.1708e-08
# Epoch 73/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4592e-04 - val_accuracy: 1.0000 - val_loss: 1.9868e-08
# Epoch 74/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 3.8767e-04 - val_accuracy: 1.0000 - val_loss: 1.5628e-08
# Epoch 75/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1814e-04 - val_accuracy: 1.0000 - val_loss: 2.0110e-08
# Epoch 76/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.3731e-05 - val_accuracy: 1.0000 - val_loss: 1.4295e-08
# Epoch 77/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 4.9269e-04 - val_accuracy: 1.0000 - val_loss: 2.0259e-05
# Epoch 78/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9999 - loss: 5.6959e-04 - val_accuracy: 1.0000 - val_loss: 4.9496e-07
# Epoch 79/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.3908e-04 - val_accuracy: 1.0000 - val_loss: 1.4210e-07
# Epoch 80/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.5778e-05 - val_accuracy: 1.0000 - val_loss: 1.1606e-07
# Epoch 81/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.3850e-05 - val_accuracy: 1.0000 - val_loss: 7.3051e-08
# Epoch 82/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2940e-04 - val_accuracy: 1.0000 - val_loss: 1.4271e-07
# Epoch 83/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.7954e-05 - val_accuracy: 1.0000 - val_loss: 4.4824e-08
# Epoch 84/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 7.0138e-04 - val_accuracy: 1.0000 - val_loss: 2.7137e-08
# Epoch 85/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9986 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 6.6994e-08
# Epoch 86/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0801e-04 - val_accuracy: 1.0000 - val_loss: 1.1509e-08
# Epoch 87/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9997 - loss: 4.4770e-04 - val_accuracy: 1.0000 - val_loss: 6.0574e-09
# Epoch 88/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 2.6246e-04 - val_accuracy: 1.0000 - val_loss: 4.9671e-09
# Epoch 89/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 3.0606e-05 - val_accuracy: 1.0000 - val_loss: 3.3921e-09
# Epoch 90/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.0471e-05 - val_accuracy: 1.0000 - val_loss: 3.3921e-09
# Epoch 91/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.0274e-04 - val_accuracy: 1.0000 - val_loss: 2.0595e-09
# Epoch 92/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.7759e-04 - val_accuracy: 1.0000 - val_loss: 1.9384e-09
# Epoch 93/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.8744e-04 - val_accuracy: 1.0000 - val_loss: 3.3921e-09
# Epoch 94/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6433e-04 - val_accuracy: 1.0000 - val_loss: 2.6652e-09
# Epoch 95/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9995 - loss: 6.5897e-04 - val_accuracy: 1.0000 - val_loss: 2.3018e-09
# Epoch 96/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2986e-04 - val_accuracy: 1.0000 - val_loss: 3.5133e-09
# Epoch 97/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.8578e-05 - val_accuracy: 1.0000 - val_loss: 2.0595e-09
# Epoch 98/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.2457e-05 - val_accuracy: 1.0000 - val_loss: 4.8459e-10
# Epoch 99/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.6483e-05 - val_accuracy: 1.0000 - val_loss: 1.9384e-09
# Epoch 100/100
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4371e-05 - val_accuracy: 1.0000 - val_loss: 2.6652e-09
# RF Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       0.50      1.00      0.67         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       1.00      1.00      1.00         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# FNN Test Accuracy: 0.9761904761904762
#                                          precision    recall  f1-score   support
#
# (vertigo) Paroymsal  Positional Vertigo       1.00      1.00      1.00         1
#                                    AIDS       1.00      1.00      1.00         1
#                                    Acne       1.00      1.00      1.00         1
#                     Alcoholic hepatitis       1.00      1.00      1.00         1
#                                 Allergy       1.00      1.00      1.00         1
#                               Arthritis       1.00      1.00      1.00         1
#                        Bronchial Asthma       1.00      1.00      1.00         1
#                    Cervical spondylosis       1.00      1.00      1.00         1
#                             Chicken pox       0.50      1.00      0.67         1
#                     Chronic cholestasis       1.00      1.00      1.00         1
#                             Common Cold       1.00      1.00      1.00         1
#                                  Dengue       1.00      1.00      1.00         1
#                               Diabetes        1.00      1.00      1.00         1
#            Dimorphic hemmorhoids(piles)       1.00      1.00      1.00         1
#                           Drug Reaction       1.00      1.00      1.00         1
#                        Fungal infection       1.00      0.50      0.67         2
#                                    GERD       1.00      1.00      1.00         1
#                         Gastroenteritis       1.00      1.00      1.00         1
#                            Heart attack       1.00      1.00      1.00         1
#                             Hepatitis B       1.00      1.00      1.00         1
#                             Hepatitis C       1.00      1.00      1.00         1
#                             Hepatitis D       1.00      1.00      1.00         1
#                             Hepatitis E       1.00      1.00      1.00         1
#                           Hypertension        1.00      1.00      1.00         1
#                         Hyperthyroidism       1.00      1.00      1.00         1
#                            Hypoglycemia       1.00      1.00      1.00         1
#                          Hypothyroidism       1.00      1.00      1.00         1
#                                Impetigo       1.00      1.00      1.00         1
#                                Jaundice       1.00      1.00      1.00         1
#                                 Malaria       1.00      1.00      1.00         1
#                                Migraine       1.00      1.00      1.00         1
#                         Osteoarthristis       1.00      1.00      1.00         1
#            Paralysis (brain hemorrhage)       1.00      1.00      1.00         1
#                     Peptic ulcer diseae       1.00      1.00      1.00         1
#                               Pneumonia       1.00      1.00      1.00         1
#                               Psoriasis       1.00      1.00      1.00         1
#                            Tuberculosis       1.00      1.00      1.00         1
#                                 Typhoid       1.00      1.00      1.00         1
#                 Urinary tract infection       1.00      1.00      1.00         1
#                          Varicose veins       1.00      1.00      1.00         1
#                             hepatitis A       1.00      1.00      1.00         1
#
#                                accuracy                           0.98        42
#                               macro avg       0.99      0.99      0.98        42
#                            weighted avg       0.99      0.98      0.98        42
# ['models/symptom_list.pkl']
